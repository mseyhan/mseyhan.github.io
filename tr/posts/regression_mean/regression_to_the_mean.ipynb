# %% [raw]
# ---
# title: "Form Yanılsaması: Futbolda Ortalamaya Dönüş"
# description: "Bu yazının Türkçe versiyonu hazırlanıyor."
# author: "Murat Seyhan"
# format:
#   html:
#     toc: true
#     toc-depth: 3
#     code-fold: false
#     code-tools: true
#     theme: cosmo
#     page-layout: full
# categories: [Football Analytics]
# ---

# %% [markdown]
# Bu yazının Türkçe versiyonu üzerinde çalışıyorum. Tam çeviri hazır olana kadar İngilizce sürüme göz atabilirsin: [The Illusion of Form: Regression to the Mean in Football](/posts/regression_mean/regression_to_the_mean.html).
#
# Çeviri hazır olduğunda bu sayfa doğrudan Türkçe içeriği gösterecek.
